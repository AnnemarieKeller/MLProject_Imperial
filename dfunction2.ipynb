# %% [markdown]
# <a href="https://colab.research.google.com/github/AnnemarieKeller/MLProject_CapstoneBlackBoxOptimisation/blob/architecture/dfunction2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# SETUP FOR COLAB TO LOAD SCRIPTS
# ===============================

# --- GitHub URL ---
GITHUB_URL = "https://github.com/AnnemarieKeller/MLProject_CapstoneBlackBoxOptimisation.git"
BRANCH = "architecture"
REPO_PATH = "/content/hello"

# Clonrepo if not already cloned
import os
import numpy as np

if not os.path.exists(REPO_PATH):
    # !git clone -b {BRANCH} {GITHUB_URL} {REPO_PATH}


# --- Option 2: Google Drive ---
# from google.colab import drive
# drive.mount('/content/drive')
# Change path below if using Drive
# repo_path = '/content/drive/MyDrive/yourrepo'

# -----------------------------
# Install scripts folder as package
# e ensures any edits to scripts are reflected immediately

# -----------------------------
# !pip uninstall -y scripts
# !pip install -e {REPO_PATH}/scripts/

import sys
sys.path.append(REPO_PATH)
import sys, os

sys.path.append(os.path.join(REPO_PATH, "scripts"))
sys.path.append(os.path.join(REPO_PATH, "scripts/utils"))

# If you update utils.py while Colab is running, you can force a reload:

# import importlib
# import scripts.utils
# importlib.reload(scripts.utils)

# Add the scripts folder to sys.path
scripts_path = os.path.abspath("../scripts")  # relative path from notebook to scripts
sys.path.append(scripts_path)
import sys
sys.path.append(f"{REPO_PATH}/scripts")

# from scripts.setup.gpBuilder import build_gp, build_svr, build_kernel_from_config

import scripts
import scripts.functionConfig as funcConfig
import scripts.accquistions as acq
import scripts.setBoundary as bound
import scripts.setup.gpBuilder as build


import scripts.BBOloop as bbo_loop  # if you saved the BBO loop in a script
# Out:
# Cloning into '/content/hello'...
# remote: Enumerating objects: 666, done.
# remote: Counting objects: 100% (218/218), done.
# remote: Compressing objects: 100% (194/194), done.
# remote: Total 666 (delta 153), reused 45 (delta 23), pack-reused 448 (from 2)
# Receiving objects: 100% (666/666), 2.13 MiB | 22.98 MiB/s, done.
# Resolving deltas: 100% (335/335), done.

# %%
import importlib
import scripts.utils
importlib.reload(scripts.utils)
# Out:
# <module 'scripts.utils' from '/content/hello/scripts/utils/__init__.py'>

# %%
functionNo = 2
weekNo = 6

# %%
from utils.weekly_data import get_weekly_inputs, get_weekly_outputs
import numpy as np
inputs = get_weekly_inputs(functionNo=functionNo,weekNo = weekNo)
outputs = get_weekly_outputs(functionNo=functionNo,weekNo = weekNo)
print(len(outputs))


X_train = np.array(inputs)

y_train = np.array(outputs)

print(X_train.shape)
print(y_train.shape)
print(X_train)
print(y_train)
# Out:
# Initial count: 10
# Weekly count: 6
# Combined: 16
# 16
# (16, 2)
# (16,)
# [[0.66579958 0.12396913]
#  [0.87779099 0.7786275 ]
#  [0.14269907 0.34900513]
#  [0.84527543 0.71112027]
#  [0.45464714 0.29045518]
#  [0.57771284 0.77197318]
#  [0.43816606 0.68501826]
#  [0.34174959 0.02869772]
#  [0.33864816 0.21386725]
#  [0.70263656 0.9265642 ]
#  [0.566581   0.045364  ]
#  [0.723782   0.206887  ]
#  [0.702637   0.926564  ]
#  [0.010819   0.996021  ]
#  [0.999067   0.028224  ]
#  [0.702637   0.926564  ]]
# [ 0.53899612  0.42058624 -0.06562362  0.29399291  0.21496451  0.02310555
#   0.24461934  0.03874902 -0.01385762  0.61120522 -0.00528752  0.45667614
#   0.68408532  0.01271428 -0.04623472  0.59364521]

# %%
from scripts.BBOloop import *
print(X_train.shape[1])

config = funcConfig.FUNCTION_CONFIG[functionNo]
best_inputwithWHite, best_outputwithWhite, historyWithWhite= (bbo_loopWith(X_train, y_train, config, "EI"))
print("best_input" , best_inputwithWHite)
print("best_outuput" , best_outputwithWhite)
print(historyWithWhite, "history")
#  0.6840853188300118 - week 5 matern
# Out:
# 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-820032202.py in <cell line: 0>()
#       3
#       4 config = funcConfig.FUNCTION_CONFIG[functionNo]
# ----> 5 best_inputwithWHite, best_outputwithWhite, historyWithWhite= (bbo_loopWith(X_train, y_train, config, "EI"))
#       6 print("best_input" , best_inputwithWHite)
#       7 print("best_outuput" , best_outputwithWhite)
#
# /content/hello/scripts/BBOloop.py in bbo_loopWith(X_train, y_train, function_config, acquisition, num_iterations, model_type, config_override, use_boundary, n_candidates, candidate_method, verbose)
#     134
#     135     if model_type.upper() == "GP":
# --> 136        surrogate = build_gpWhiteKernel(function_config, X_train, y_train,config_override)
#     137     elif model_type.upper() == "SVR":
#     138        surrogate = build_svr(X_train, y_train, function_config,config_override)
#
# /content/hello/scripts/setup/gpBuilder.py in build_gpWhiteKernel(config, X_train, y_train, kernel_override, use_seed, seed)
#      39     input_dim = X_train.shape[1] if X_train is not None else None
#      40
# ---> 41     kernel = build_kernelWithWhiteKernel(
#      42         config = config,
#      43         input_dim=input_dim,
#
# /content/hello/scripts/setup/kernelBuilding.py in build_kernelWithWhiteKernel(config, input_dim, kernel_override)
#     304
#     305     # Instantiate kernel
# --> 306     kernel = kernel_cls(**kwargs)
#     307
#     308     # ----- Add WhiteKernel if requested -----
#
# TypeError: RBF.__init__() got an unexpected keyword argument 'nu'
